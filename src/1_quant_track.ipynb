# %% [markdown]
# # Notebook for the Quant Track
# ### Author: Marcello Maugeri
# #### RNDM Tournament @ Encode London 2024

# %% [markdown]
# ### Getting started:
# - Create a virtual environment with `python3.11 -m venv venv` (tested on Python 3.11, but Python 3.12 should be fine)
# - Activate it with `source venv/bin/activate`
# - Before running the notebook, please be sure to read the README.md in this folder, as it explains how to get data from BigQuery. In any case, pre-fetched data are already present in the `data` folder.
# - Run the notebook (be sure to select the venv as kernel)

# %%
#This will install all the requirements 
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: aiohappyeyeballs==2.4.3 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (2.4.3)
# Requirement already satisfied: aiohttp==3.10.10 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (3.10.10)
# Requirement already satisfied: aiosignal==1.3.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: annotated-types==0.7.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: anyio==4.6.2.post1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (4.6.2.post1)
# Requirement already satisfied: appnope==0.1.4 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.1.4)
# Requirement already satisfied: asttokens==2.4.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (2.4.1)
# Requirement already satisfied: attrs==24.2.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (24.2.0)
# Requirement already satisfied: bitarray==3.0.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (3.0.0)
# Requirement already satisfied: certifi==2024.8.30 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (2024.8.30)
# Requirement already satisfied: charset-normalizer==3.4.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (3.4.0)
# Requirement already satisfied: ckzg==2.0.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (2.0.1)
# Requirement already satisfied: comm==0.2.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (1.3.0)
# Requirement already satisfied: cycler==0.12.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (0.12.1)
# Requirement already satisfied: cytoolz==1.0.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (1.0.0)
# Requirement already satisfied: dateparser==1.2.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (1.2.0)
# Requirement already satisfied: db-dtypes==1.3.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (1.3.0)
# Requirement already satisfied: debugpy==1.8.7 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (1.8.7)
# Requirement already satisfied: decorator==5.1.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (5.1.1)
# Requirement already satisfied: distro==1.9.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (1.9.0)
# Requirement already satisfied: eth-account==0.13.4 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 22)) (0.13.4)
# Requirement already satisfied: eth-hash==0.7.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (0.7.0)
# Requirement already satisfied: eth-keyfile==0.8.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 24)) (0.8.1)
# Requirement already satisfied: eth-keys==0.6.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 25)) (0.6.0)
# Requirement already satisfied: eth-rlp==2.1.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 26)) (2.1.0)
# Requirement already satisfied: eth-typing==5.0.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 27)) (5.0.1)
# Requirement already satisfied: eth-utils==5.1.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 28)) (5.1.0)
# Requirement already satisfied: eth_abi==5.1.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 29)) (5.1.0)
# Requirement already satisfied: executing==2.1.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (2.1.0)
# Requirement already satisfied: fonttools==4.54.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 31)) (4.54.1)
# Requirement already satisfied: frozenlist==1.5.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 32)) (1.5.0)
# Requirement already satisfied: h11==0.14.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 33)) (0.14.0)
# Requirement already satisfied: hexbytes==1.2.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 34)) (1.2.1)
# Requirement already satisfied: httpcore==1.0.6 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 35)) (1.0.6)
# Requirement already satisfied: httpx==0.27.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 36)) (0.27.2)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 37)) (0.4.0)
# Requirement already satisfied: idna==3.10 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 38)) (3.10)
# Requirement already satisfied: ipykernel==6.29.5 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 39)) (6.29.5)
# Requirement already satisfied: ipython==8.29.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 40)) (8.29.0)
# Requirement already satisfied: jedi==0.19.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 41)) (0.19.1)
# Requirement already satisfied: jiter==0.6.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 42)) (0.6.1)
# Requirement already satisfied: joblib==1.4.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 43)) (1.4.2)
# Requirement already satisfied: jsonpatch==1.33 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 44)) (1.33)
# Requirement already satisfied: jsonpointer==3.0.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 45)) (3.0.0)
# Requirement already satisfied: jupyter_client==8.6.3 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 46)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 47)) (5.7.2)
# Requirement already satisfied: kiwisolver==1.4.7 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 48)) (1.4.7)
# Requirement already satisfied: langchain-core==0.3.13 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 49)) (0.3.13)
# Requirement already satisfied: langchain-openai==0.2.3 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 50)) (0.2.3)
# Requirement already satisfied: langgraph==0.2.39 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 51)) (0.2.39)
# Requirement already satisfied: langgraph-checkpoint==2.0.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 52)) (2.0.2)
# Requirement already satisfied: langgraph-sdk==0.1.34 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 53)) (0.1.34)
# Requirement already satisfied: langsmith==0.1.137 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 54)) (0.1.137)
# Requirement already satisfied: matplotlib==3.9.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 55)) (3.9.2)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 56)) (0.1.7)
# Requirement already satisfied: msgpack==1.1.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 57)) (1.1.0)
# Requirement already satisfied: multidict==6.1.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 58)) (6.1.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 59)) (1.6.0)
# Requirement already satisfied: numpy==2.1.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 60)) (2.1.2)
# Requirement already satisfied: openai==1.52.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 61)) (1.52.2)
# Requirement already satisfied: orjson==3.10.10 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 62)) (3.10.10)
# Requirement already satisfied: packaging==24.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 63)) (24.1)
# Requirement already satisfied: pandas==2.2.3 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 64)) (2.2.3)
# Requirement already satisfied: parsimonious==0.10.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 65)) (0.10.0)
# Requirement already satisfied: parso==0.8.4 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 66)) (0.8.4)
# Requirement already satisfied: pexpect==4.9.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 67)) (4.9.0)
# Requirement already satisfied: pillow==11.0.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 68)) (11.0.0)
# Requirement already satisfied: platformdirs==4.3.6 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 69)) (4.3.6)
# Requirement already satisfied: prompt_toolkit==3.0.48 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 70)) (3.0.48)
# Requirement already satisfied: propcache==0.2.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 71)) (0.2.0)
# Requirement already satisfied: psutil==6.1.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 72)) (6.1.0)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 73)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 74)) (0.2.3)
# Requirement already satisfied: pyarrow==17.0.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 75)) (17.0.0)
# Requirement already satisfied: pycryptodome==3.21.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 76)) (3.21.0)
# Requirement already satisfied: pydantic==2.9.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 77)) (2.9.2)
# Requirement already satisfied: pydantic_core==2.23.4 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 78)) (2.23.4)
# Requirement already satisfied: Pygments==2.18.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 79)) (2.18.0)
# Requirement already satisfied: pyparsing==3.2.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 80)) (3.2.0)
# Requirement already satisfied: python-binance==1.0.21 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 81)) (1.0.21)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 82)) (2.9.0.post0)
# Requirement already satisfied: pytz==2024.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 83)) (2024.2)
# Requirement already satisfied: pyunormalize==16.0.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 84)) (16.0.0)
# Requirement already satisfied: PyYAML==6.0.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 85)) (6.0.2)
# Requirement already satisfied: pyzmq==26.2.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 86)) (26.2.0)
# Requirement already satisfied: regex==2024.9.11 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 87)) (2024.9.11)
# Requirement already satisfied: requests==2.32.3 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 88)) (2.32.3)
# Requirement already satisfied: requests-toolbelt==1.0.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 89)) (1.0.0)
# Requirement already satisfied: rlp==4.0.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 90)) (4.0.1)
# Requirement already satisfied: scikit-learn==1.5.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 91)) (1.5.2)
# Requirement already satisfied: scipy==1.14.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 92)) (1.14.1)
# Requirement already satisfied: six==1.16.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 93)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 94)) (1.3.1)
# Requirement already satisfied: stack-data==0.6.3 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 95)) (0.6.3)
# Requirement already satisfied: tenacity==9.0.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 96)) (9.0.0)
# Requirement already satisfied: threadpoolctl==3.5.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 97)) (3.5.0)
# Requirement already satisfied: tiktoken==0.8.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 98)) (0.8.0)
# Requirement already satisfied: toolz==1.0.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 99)) (1.0.0)
# Requirement already satisfied: tornado==6.4.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 100)) (6.4.1)
# Requirement already satisfied: tqdm==4.66.5 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 101)) (4.66.5)
# Requirement already satisfied: traitlets==5.14.3 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 102)) (5.14.3)
# Requirement already satisfied: types-requests==2.32.0.20241016 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 103)) (2.32.0.20241016)
# Requirement already satisfied: typing_extensions==4.12.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 104)) (4.12.2)
# Requirement already satisfied: tzdata==2024.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 105)) (2024.2)
# Requirement already satisfied: tzlocal==5.2 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 106)) (5.2)
# Requirement already satisfied: ujson==5.10.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 107)) (5.10.0)
# Requirement already satisfied: urllib3==2.2.3 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 108)) (2.2.3)
# Requirement already satisfied: wcwidth==0.2.13 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 109)) (0.2.13)
# Requirement already satisfied: web3==7.4.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 110)) (7.4.0)
# Requirement already satisfied: websockets==13.1 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 111)) (13.1)
# Requirement already satisfied: yarl==1.16.0 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 112)) (1.16.0)
# Requirement already satisfied: zelos-demeter==0.7.4 in /Users/marcellomaugeri/Documents/Proteus/venv/lib/python3.11/site-packages (from -r requirements.txt (line 113)) (0.7.4)

# %%
#Imports
import pandas as pd
import numpy as np
import glob
import os
import json
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from ta.trend import ADXIndicator

# %% [markdown]
# ### Data Selection and Aggregation
#
# The objective of this notebook is to analyze data from Aave V3 in the Polygon network for the tokens WETH and USDC.
#
# The data is composed of two parts:
# - **sample** contains data obtained from BigQuery providing `liquidity_rate`,`stable_borrow_rate`,`variable_borrow_rate`,`liquidity_index`,`variable_borrow_index` for both tokens.
# In particular, the addresses are:
#     - `0x2791Bca1f2de4661ED88A30C99A7a9449Aa84174` for `usdc`
#     - `0x7ceB23fD6bC0adD59E62ac25578270cFf1b9f619` for `weth`
# - **volatility_data_june_2024** contains the assets value for `usdc` and `weth` obtained from the pycoingecko API.
#
# Since the **sample** data are measured every minute, the first step is to standardize the volatility data into a table with a timestamp for every minute, aligning it with the sample data.
#
# The output would be found in `../data/WETH_USDC_Prices.csv`.

# %%
# Function to read JSON data from a file
def read_prices_from_file(filename):
    try:
        with open(filename, 'r') as file:
            data = json.load(file)
        return data['prices']
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON from file '{filename}': {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Function to create a DataFrame from price data
def create_price_dataframe(prices):
    # Convert timestamps to datetime and create a DataFrame
    timestamps = [datetime.fromtimestamp(item[0] / 1000) for item in prices]
    prices_values = [item[1] for item in prices]
    df = pd.DataFrame({'timestamp': timestamps, 'price': prices_values})
    df.set_index('timestamp', inplace=True)
    return df

# Read WETH and USDC prices
weth_prices = read_prices_from_file('../data/volatility_data_june_2024/aave-polygon-weth.json')
usdc_prices = read_prices_from_file('../data/volatility_data_june_2024/aave-polygon-usdc.json')

# Create DataFrames
weth_daily_daily_daily_df = create_price_dataframe(weth_prices)
usdc_df = create_price_dataframe(usdc_prices)

# Define the time range for the entire month of June 2024
start_time = datetime(2024, 6, 1, 0, 0)
end_time = datetime(2024, 6, 30, 23, 59)
all_times = pd.date_range(start=start_time, end=end_time, freq='T')

# Initialize indices and current price holders
weth_idx = 0
usdc_idx = 0
weth_len = len(weth_df)
usdc_len = len(usdc_df)

# Create a results list
results = []

# Initialize with the first values from the DataFrames
current_weth = weth_df.iloc[0]['price'] if weth_len > 0 else None
current_usdc = usdc_df.iloc[0]['price'] if usdc_len > 0 else None

# Loop through each minute in the time range
for current_time in all_times:
    # Check for current WETH price if within bounds
    if weth_idx < weth_len and weth_df.index[weth_idx] <= current_time:
        current_weth = weth_df.iloc[weth_idx]['price']
        weth_idx += 1

    # Check for current USDC price if within bounds
    if usdc_idx < usdc_len and usdc_df.index[usdc_idx] <= current_time:
        current_usdc = usdc_df.iloc[usdc_idx]['price']
        usdc_idx += 1

    # Add the current time and prices to results
    results.append([current_time, current_weth, current_usdc])

# Create a final DataFrame
df = pd.DataFrame(results, columns=['timestamp', 'WETH', 'USDC'])

# Format the timestamp for the output
df['timestamp'] = df['timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S')

# Save to CSV
df.to_csv('../data/WETH_USDC_Prices.csv', index=False, header=['', 'WETH', 'USDC'])

df.head()
# Out:
# /var/folders/ch/f52gc87d5_7b95m4hg7qfbj80000gn/T/ipykernel_53810/3214608902.py:34: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   all_times = pd.date_range(start=start_time, end=end_time, freq='T')
#              timestamp         WETH     USDC
# 0  2024-06-01 00:00:00  3769.771717  1.00069
# 1  2024-06-01 00:01:00  3769.771717  1.00069
# 2  2024-06-01 00:02:00  3769.771717  1.00069
# 3  2024-06-01 00:03:00  3769.771717  1.00069
# 4  2024-06-01 00:04:00  3769.771717  1.00069

# %% [markdown]
# Now we can join the current dataframe with the liquidity and borrow rates for both tokens from the `sample` folder.

# %%
folder_path="../data/sample/"

# --- Step 1: Process 'weth' data ---

# Create an empty list to store the 'weth' DataFrames
weth_dfs = []

# Loop through all 'weth' CSV files in the folder
for file in glob.glob(folder_path + '*-0x7ceb23fd6bc0add59e62ac25578270cff1b9f619-*.minute.csv'):  # Filter for 'weth' files
    # Read the CSV file into a pandas DataFrame
    temp_df = pd.read_csv(file)

    # Rename columns by prepending 'weth'
    columns_to_rename = {
        'liquidity_rate': 'weth_liquidity_rate',
        'stable_borrow_rate': 'weth_stable_borrow_rate',
        'variable_borrow_rate': 'weth_variable_borrow_rate',
        'liquidity_index': 'weth_liquidity_index',
        'variable_borrow_index': 'weth_variable_borrow_index'
    }
    temp_df = temp_df.rename(columns=columns_to_rename)

    # Add the DataFrame to the list
    weth_dfs.append(temp_df)

# Concatenate all 'weth' DataFrames
weth_combined_df = pd.concat(weth_dfs)

# Merge the 'weth' DataFrame
weth_combined_df = pd.merge(df, weth_combined_df, left_on='timestamp', right_on='block_timestamp').drop("block_timestamp", axis=1)

weth_combined_df.head(5)
# Out:
#              timestamp         WETH     USDC  weth_liquidity_rate  \
# 0  2024-06-01 00:00:00  3769.771717  1.00069             0.004649
# 1  2024-06-01 00:01:00  3769.771717  1.00069             0.004649
# 2  2024-06-01 00:02:00  3769.771717  1.00069             0.004649
# 3  2024-06-01 00:03:00  3769.771717  1.00069             0.004649
# 4  2024-06-01 00:04:00  3769.771717  1.00069             0.004649
#
#    weth_stable_borrow_rate  weth_variable_borrow_rate  weth_liquidity_index  \
# 0                 0.076128                   0.020831              1.010326
# 1                 0.076128                   0.020831              1.010326
# 2                 0.076128                   0.020831              1.010326
# 3                 0.076128                   0.020831              1.010326
# 4                 0.076128                   0.020831              1.010326
#
#    weth_variable_borrow_index
# 0                    1.043067
# 1                    1.043067
# 2                    1.043067
# 3                    1.043067
# 4                    1.043067

# %%
# --- Step 2: Process 'usdc' data ---

# Create an empty list to store the 'usdc' DataFrames
usdc_dfs = []

# Loop through all 'usdc' CSV files in the folder
for file in glob.glob(folder_path + '*-0x2791bca1f2de4661ed88a30c99a7a9449aa84174-*.minute.csv'):  # Filter for 'usdc' files
    # Read the CSV file into a pandas DataFrame
    temp_df = pd.read_csv(file)

    # Rename columns by prepending 'usdc'
    columns_to_rename = {
        'liquidity_rate': 'usdc_liquidity_rate',
        'stable_borrow_rate': 'usdc_stable_borrow_rate',
        'variable_borrow_rate': 'usdc_variable_borrow_rate',
        'liquidity_index': 'usdc_liquidity_index',
        'variable_borrow_index': 'usdc_variable_borrow_index'
    }
    temp_df = temp_df.rename(columns=columns_to_rename)
    
    # Add the DataFrame to the list
    usdc_dfs.append(temp_df)

# Concatenate all 'weth' DataFrames
usdc_combined_df = pd.concat(usdc_dfs)

# Merge the 'weth' DataFrame
all_combined_df = pd.merge(weth_combined_df, usdc_combined_df, left_on='timestamp', right_on='block_timestamp').drop("block_timestamp", axis=1)

all_combined_df.to_csv('../data/all_combined.csv', index=False)

all_combined_df.head(5)
# Out:
#              timestamp         WETH     USDC  weth_liquidity_rate  \
# 0  2024-06-01 00:00:00  3769.771717  1.00069             0.004649
# 1  2024-06-01 00:01:00  3769.771717  1.00069             0.004649
# 2  2024-06-01 00:02:00  3769.771717  1.00069             0.004649
# 3  2024-06-01 00:03:00  3769.771717  1.00069             0.004649
# 4  2024-06-01 00:04:00  3769.771717  1.00069             0.004649
#
#    weth_stable_borrow_rate  weth_variable_borrow_rate  weth_liquidity_index  \
# 0                 0.076128                   0.020831              1.010326
# 1                 0.076128                   0.020831              1.010326
# 2                 0.076128                   0.020831              1.010326
# 3                 0.076128                   0.020831              1.010326
# 4                 0.076128                   0.020831              1.010326
#
#    weth_variable_borrow_index  usdc_liquidity_rate  usdc_stable_borrow_rate  \
# 0                    1.043067             0.066019                 0.114905
# 1                    1.043067             0.066021                 0.114905
# 2                    1.043067             0.066022                 0.114905
# 3                    1.043067             0.066022                 0.114905
# 4                    1.043067             0.066022                 0.114905
#
#    usdc_variable_borrow_rate  usdc_liquidity_index  usdc_variable_borrow_index
# 0                   0.098100              1.093715                    1.136930
# 1                   0.098102              1.093716                    1.136931
# 2                   0.098102              1.093716                    1.136931
# 3                   0.098102              1.093716                    1.136931
# 4                   0.098102              1.093716                    1.136931

# %%
# Now, to avoid confusion, let's rename the dataframe
df = all_combined_df
# Let's see a descriptive statistics
df.describe()
# Out:
#                WETH          USDC  weth_liquidity_rate  \
# count  43200.000000  43200.000000         43200.000000
# mean    3570.665013      0.999954             0.004560
# std      156.428130      0.001039             0.000265
# min     3269.471031      0.990930             0.004071
# 25%     3445.561727      0.999620             0.004454
# 50%     3525.877361      0.999981             0.004639
# 75%     3692.368400      1.000279             0.004734
# max     3873.330017      1.013684             0.005036
#
#        weth_stable_borrow_rate  weth_variable_borrow_rate  \
# count             43200.000000               43200.000000
# mean                  0.074681                   0.020376
# std                   0.002695                   0.000938
# min                   0.069833                   0.018662
# 25%                   0.075762                   0.020529
# 50%                   0.076111                   0.020816
# 75%                   0.076285                   0.020960
# max                   0.076834                   0.021413
#
#        weth_liquidity_index  weth_variable_borrow_index  usdc_liquidity_rate  \
# count          43200.000000                43200.000000         43200.000000
# mean               1.010536                    1.043958             0.067674
# std                0.000121                    0.000510             0.021655
# min                1.010326                    1.043067             0.044919
# 25%                1.010432                    1.043515             0.056021
# 50%                1.010540                    1.043967             0.063216
# 75%                1.010641                    1.044412             0.067282
# max                1.010742                    1.044815             0.250051
#
#        usdc_stable_borrow_rate  usdc_variable_borrow_rate  \
# count             43200.000000               43200.000000
# mean                  0.122247                   0.104175
# std                   0.020302                   0.029533
# min                   0.114028                   0.080557
# 25%                   0.114513                   0.090252
# 50%                   0.114796                   0.095928
# 75%                   0.114958                   0.099165
# max                   0.314232                   0.365643
#
#        usdc_liquidity_index  usdc_variable_borrow_index
# count          43200.000000                43200.000000
# mean               1.097142                    1.142252
# std                0.001758                    0.002784
# min                1.093715                    1.136930
# 25%                1.095776                    1.140069
# 50%                1.097365                    1.142503
# 75%                1.098674                    1.144660
# max                1.099853                    1.146706

# %% [markdown]
# #### General observation
# - **Count**: We have 43200 data points for each variable, which is a good amount of data for analysis. This represents minute-level data for the entire month of June (30 days * 24 hours * 60 minutes = 43,200 minutes).
# - **Mean vs. Median (50%)**: For most variables, the mean and median are quite close, suggesting a roughly symmetrical distribution of the data. However, there are some exceptions (like usdc_stable_borrow_rate, and usdc_variable_borrow_rate), where the mean is higher than the median, indicating a right-skewed distribution (some larger values are pulling the mean up).
# - **WETH**: The average price of WETH in June was around 3570.67, with a standard deviation of 156.43, indicating some price fluctuation. The minimum and maximum values show the price range during the month.
# - **USDC**: As expected, the USDC price remains relatively stable around 1.00. The small standard deviation confirms this stability.
# - **Liquidity Rates** (weth_liquidity_rate, usdc_liquidity_rate): These rates represent the returns earned by liquidity providers. The average liquidity rate for WETH is much lower (0.00456) than for USDC (0.067674). The large standard deviation and the max value for usdc_liquidity_rate suggest significant variability and potentially some outliers or unusual spikes in the USDC liquidity rate.
# - **Borrow Rates** (weth_stable_borrow_rate, weth_variable_borrow_rate, usdc_stable_borrow_rate, usdc_variable_borrow_rate): These rates show the cost of borrowing. In general, USDC borrow rates are higher than WETH borrow rates. The variability in borrow rates is also higher for USDC, especially for the stable borrow rate.
# - **Liquidity and Borrow Indices** (weth_liquidity_index, weth_variable_borrow_index, usdc_liquidity_index, usdc_variable_borrow_index): These indices track the cumulative changes in liquidity and borrow rates over time. The relatively small standard deviations indicate that these indices generally trend upwards gradually.

# %%
# Extract the 'WETH' and 'USDC' columns
weth_prices = df['WETH']
usdc_prices = df['USDC']

# Normalize the prices using Min-Max scaling
normalized_weth = (weth_prices - weth_prices.min()) / (weth_prices.max() - weth_prices.min())
normalized_usdc = (usdc_prices - usdc_prices.min()) / (usdc_prices.max() - usdc_prices.min())

# --- Plot the normalized prices ---
plt.figure(figsize=(10, 6))

# Plot normalized WETH prices
plt.plot(df['timestamp'], normalized_weth, label='Normalized WETH')

# Plot normalized USDC prices
plt.plot(df['timestamp'], normalized_usdc, label='Normalized USDC')

# Set plot labels and title
plt.xlabel('Timestamp')
plt.ylabel('Normalized Price')
plt.title('Normalized WETH and USDC Prices Over Time')
plt.legend()
plt.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# At first sight there is no clear correlation between the two variables. To quantify this, we can calculate the Pearson coefficient.

# %%
# Calculate the Pearson correlation coefficient and p-value
correlation, p_value = pearsonr(normalized_weth, normalized_usdc)

# Print the results
print(f"Pearson Correlation between normalized WETH and USDC prices: {correlation}")
print(f"P-value: {p_value}")
# Out:
# Pearson Correlation between normalized WETH and USDC prices: 0.10300329610292301
# P-value: 3.284392198413366e-102

# %% [markdown]
# - The **Pearson Correlation Coefficient** shows a weak positive correlation. A positive correlation means that that as the normalized price of WETH increases, the normalized price of USDC tends to increase slightly as well (and vice versa).
# - The **p-value** is extremely small (essentially zero). This means that the observed correlation is highly statistically significant. In other words, it is very unlikely to have occurred by chance alone.
# The agent could leverage this indicator for market prediction

# %% [markdown]
# The next step is to measure two important indicators in trading strategies.
# The first metric is the **EMA Bearish Crossover**, a technical analysis signal that indicates a potential downward trend or selling opportunity. It occurs when a short-term Exponential Moving Average (EMA) crosses below a longer-term EMA. This crossover suggests that the momentum is shifting from bullish (upward) to bearish (downward), which traders often interpret as a sell signal. Since we have data for one month only, we will consider a popular strategy which is the 5-8-13 EMA. In brief, when the 5-EMA crosses above the 8 and 13 EMAs, it suggests a rising bullish momentum (). When the opposite happens, it indicates bearish momentum.

# %%
# Create a copy of 'df'
daily_df = df.copy()

# Ensure 'timestamp' is a DatetimeIndex before resampling
daily_df['timestamp'] = pd.to_datetime(daily_df['timestamp'])
daily_df = daily_df.set_index('timestamp')

# Resample to daily frequency and take the first row of each day
daily_df = daily_df.resample('D').first()

# Reset the index to have 'timestamp' as a column again
daily_df = daily_df.reset_index()

# Now you can convert 'timestamp' to datetime if needed
daily_df['timestamp'] = pd.to_datetime(daily_df['timestamp']) 

# --- Calculate EMAs ---

# Calculate the 5, 8, and 13 EMA for WETH liquidity rate
daily_df['weth_liquidity_rate_ema_5'] = daily_df['weth_liquidity_rate'].ewm(span=5, adjust=False).mean()
daily_df['weth_liquidity_rate_ema_8'] = daily_df['weth_liquidity_rate'].ewm(span=8, adjust=False).mean()
daily_df['weth_liquidity_rate_ema_13'] = daily_df['weth_liquidity_rate'].ewm(span=13, adjust=False).mean()

# Calculate the 5, 8, and 13 EMA for USDC liquidity rate
daily_df['usdc_liquidity_rate_ema_5'] = daily_df['usdc_liquidity_rate'].ewm(span=5, adjust=False).mean()
daily_df['usdc_liquidity_rate_ema_8'] = daily_df['usdc_liquidity_rate'].ewm(span=8, adjust=False).mean()
daily_df['usdc_liquidity_rate_ema_13'] = daily_df['usdc_liquidity_rate'].ewm(span=13, adjust=False).mean()

def identify_bearish_crossover(row, token, prev_state): 
    ema_5 = row[f'{token}_liquidity_rate_ema_5']
    ema_8 = row[f'{token}_liquidity_rate_ema_8']
    ema_13 = row[f'{token}_liquidity_rate_ema_13']

    if ema_5 < ema_8 and ema_5 < ema_13 and prev_state[token]:
        prev_state[token] = False  # Update state: crossover happened
        return True
    else:
        prev_state[token] = ema_5 > ema_8 or ema_5 > ema_13  # Update state
        return False

# Initialize the previous state
prev_state = {'weth': True, 'usdc': True}  

# Apply the function
daily_df['weth_bearish_crossover'] = daily_df.apply(lambda row: identify_bearish_crossover(row, 'weth', prev_state), axis=1)
daily_df['usdc_bearish_crossover'] = daily_df.apply(lambda row: identify_bearish_crossover(row, 'usdc', prev_state), axis=1)

# %%
daily_df.head(10)
# Out:
#    timestamp         WETH      USDC  weth_liquidity_rate  \
# 0 2024-06-01  3769.771717  1.000690             0.004649
# 1 2024-06-02  3813.872765  1.000137             0.004663
# 2 2024-06-03  3785.229342  0.999328             0.004623
# 3 2024-06-04  3774.909954  0.999482             0.004740
# 4 2024-06-05  3818.432072  1.000623             0.004692
# 5 2024-06-06  3851.056672  0.999649             0.004671
# 6 2024-06-07  3797.530389  0.999978             0.004697
# 7 2024-06-08  3690.513151  0.999314             0.004769
# 8 2024-06-09  3678.831802  0.999695             0.004799
# 9 2024-06-10  3714.723924  0.998882             0.004819
#
#    weth_stable_borrow_rate  weth_variable_borrow_rate  weth_liquidity_index  \
# 0                 0.076128                   0.020831              1.010326
# 1                 0.076154                   0.020852              1.010339
# 2                 0.076080                   0.020791              1.010352
# 3                 0.076296                   0.020969              1.010366
# 4                 0.076208                   0.020896              1.010379
# 5                 0.076170                   0.020865              1.010395
# 6                 0.076217                   0.020904              1.010408
# 7                 0.076349                   0.021013              1.010425
# 8                 0.076405                   0.021059              1.010439
# 9                 0.076442                   0.021090              1.010452
#
#    weth_variable_borrow_index  usdc_liquidity_rate  usdc_stable_borrow_rate  \
# 0                    1.043067             0.066019                 0.114905
# 1                    1.043126             0.063270                 0.114798
# 2                    1.043186             0.068525                 0.115000
# 3                    1.043245             0.138360                 0.193515
# 4                    1.043305             0.131596                 0.185961
# 5                    1.043365             0.097982                 0.148310
# 6                    1.043425             0.066508                 0.114928
# 7                    1.043485             0.066950                 0.114946
# 8                    1.043545             0.066582                 0.114932
# 9                    1.043605             0.067216                 0.114956
#
#    ...  usdc_liquidity_index  usdc_variable_borrow_index  \
# 0  ...              1.093715                    1.136930
# 1  ...              1.093912                    1.137233
# 2  ...              1.094114                    1.137548
# 3  ...              1.094460                    1.138074
# 4  ...              1.094809                    1.138610
# 5  ...              1.095155                    1.139142
# 6  ...              1.095457                    1.139593
# 7  ...              1.095677                    1.139916
# 8  ...              1.095877                    1.140224
# 9  ...              1.096079                    1.140534
#
#    weth_liquidity_rate_ema_5  weth_liquidity_rate_ema_8  \
# 0                   0.004649                   0.004649
# 1                   0.004654                   0.004652
# 2                   0.004643                   0.004646
# 3                   0.004676                   0.004667
# 4                   0.004681                   0.004672
# 5                   0.004678                   0.004672
# 6                   0.004684                   0.004678
# 7                   0.004712                   0.004698
# 8                   0.004741                   0.004720
# 9                   0.004767                   0.004742
#
#    weth_liquidity_rate_ema_13  usdc_liquidity_rate_ema_5  \
# 0                    0.004649                   0.066019
# 1                    0.004651                   0.065103
# 2                    0.004647                   0.066244
# 3                    0.004660                   0.090282
# 4                    0.004665                   0.104054
# 5                    0.004666                   0.102030
# 6                    0.004670                   0.090189
# 7                    0.004684                   0.082443
# 8                    0.004701                   0.077156
# 9                    0.004718                   0.073842
#
#    usdc_liquidity_rate_ema_8  usdc_liquidity_rate_ema_13  \
# 0                   0.066019                    0.066019
# 1                   0.065408                    0.065626
# 2                   0.066101                    0.066041
# 3                   0.082159                    0.076372
# 4                   0.093145                    0.084261
# 5                   0.094220                    0.086221
# 6                   0.088061                    0.083405
# 7                   0.083370                    0.081054
# 8                   0.079639                    0.078987
# 9                   0.076878                    0.077305
#
#    weth_bearish_crossover  usdc_bearish_crossover
# 0                   False                   False
# 1                   False                   False
# 2                    True                   False
# 3                   False                   False
# 4                   False                   False
# 5                   False                   False
# 6                   False                   False
# 7                   False                   False
# 8                   False                    True
# 9                   False                   False
#
# [10 rows x 21 columns]

# %%
# --- Visualization ---

plt.figure(figsize=(12, 6))

# Plot the bearish crossover signals for WETH (filtered data)
plt.plot(daily_df['timestamp'], daily_df['weth_bearish_crossover'].astype(int), label='WETH Bearish Crossover', marker='o')

# Plot the bearish crossover signals for USDC (filtered data)
plt.plot(daily_df['timestamp'], daily_df['usdc_bearish_crossover'].astype(int), label='USDC Bearish Crossover', marker='x')

# Set plot labels and title
plt.xlabel('Timestamp')
plt.ylabel('Crossover Signal')
plt.title('5-8-13 EMA Bearish Crossover Signals for WETH and USDC')
plt.legend()

# Set y-axis limits
plt.ylim(-0.1, 1.1)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# The 5-8-13 EMA bearish crossover suggests four times (2 for WETH and 2 for USDC) when the price goes down.
# In fact, if you scroll up again for the price trend graph, you could see that in the same positions there is a price drop.

# %% [markdown]
# The EMA and other indicators are often complemented by measuring the **ADX**. The ADX is a lagging indicator, so it is best used in conjunction with other indicators to confirm trends.
# The typical interpretation of ADX values is:
# - ADX > 25: **Strong trend**
# - ADX < 20: **Weak or no trend**

# %%
adx_df = df[['timestamp', 'WETH', "USDC"]]

# Convert the 'timestamp' column to datetime objects
adx_df['timestamp'] = pd.to_datetime(adx_df['timestamp'])

# Set 'timestamp' as the index
adx_df = adx_df.set_index('timestamp')

# Resample to daily frequency and calculate the opening, maximum, and closing values
def ohlc(x):
    return pd.Series({'WETH_low': x['WETH'].min(),
                      'WETH_max': x['WETH'].max(),
                      'WETH_close': x['WETH'].iloc[-1],
                      'USDC_low': x['USDC'].min(),
                      'USDC_max': x['USDC'].max(),
                      'USDC_close': x['USDC'].iloc[-1]})

adx_df = adx_df.resample('D').apply(ohlc).reset_index()

adx_df.head(5)
# Out:
# /var/folders/ch/f52gc87d5_7b95m4hg7qfbj80000gn/T/ipykernel_53810/3396798787.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   adx_df['timestamp'] = pd.to_datetime(adx_df['timestamp'])
#    timestamp     WETH_low     WETH_max   WETH_close  USDC_low  USDC_max  \
# 0 2024-06-01  3761.563153  3813.872765  3813.872765  0.998038  1.000690
# 1 2024-06-02  3767.668382  3825.858530  3785.229342  0.999311  1.002602
# 2 2024-06-03  3771.446764  3838.021727  3774.909954  0.997623  1.001965
# 3 2024-06-04  3745.622306  3822.200657  3818.432072  0.998796  1.004104
# 4 2024-06-05  3790.455527  3873.330017  3851.056672  0.998740  1.013684
#
#    USDC_close
# 0    1.000137
# 1    0.999328
# 2    0.999482
# 3    1.000623
# 4    0.999649

# %%
wethADX = ADXIndicator(adx_df['WETH_max'],adx_df['WETH_low'],adx_df['WETH_close'],14,False)
adx_df['weth_pos_directional_indicator'] = wethADX.adx_pos()
adx_df['weth_neg_directional_indicator'] = wethADX.adx_neg()
adx_df['weth_adx'] = wethADX.adx()

# %%
adx_df['trend'] = np.where(adx_df['weth_adx']>25,adx_df['WETH_close'],np.nan)
adx_df['trend_signal'] = np.where(adx_df['weth_adx']>25,1,0)
plt.figure(figsize=(10,7))
plt.grid()
plt.plot(adx_df['WETH_close'])
plt.plot(adx_df['trend'])
plt.ylabel('WETH Value')
plt.xlabel('Date')
plt.show()

# %%
usdcADX = ADXIndicator(adx_df['USDC_max'],adx_df['USDC_low'],adx_df['USDC_close'],14,False)
adx_df['usdc_pos_directional_indicator'] = usdcADX.adx_pos()
adx_df['usdc_neg_directional_indicator'] = usdcADX.adx_neg()
adx_df['usdc_adx'] = usdcADX.adx()
adx_df['trend'] = np.where(adx_df['usdc_adx']>25,adx_df['USDC_close'],np.nan)
adx_df['trend_signal'] = np.where(adx_df['usdc_adx']>25,1,0)
plt.figure(figsize=(10,7))
plt.grid()
plt.plot(adx_df['USDC_close'])
plt.plot(adx_df['trend'])
plt.ylabel('USDC Value')
plt.xlabel('Date')
plt.show()

# %% [markdown]
# The last two graphs proposed shows the daily trend for a token. The orange line suggests when the ADX is higher than 25.

# %% [markdown]
# ### Conclusions
# The market in July 2024 was relatively stable, with a decline in the value of tokens. It is reasonable to posit that an agent such as Proteus would be able to anticipate this and provide WETH tokens before the midpoint of the month. It should be noted that Proteus operates off-chain, employing the Demeter framework to backtest a strategy.
# To continue to explore the Proteus project, please, run the script `2_simple_backtest.py`
